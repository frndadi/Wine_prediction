# %% [markdown]
# <a href="https://colab.research.google.com/github/frndadi/Wine_prediction/blob/main/WineDataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-07de91dd-3926-4e39-ab2e-d7584fb4fa8b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-07de91dd-3926-4e39-ab2e-d7584fb4fa8b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv('winequality-red.csv')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
df['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

corr = df.corr()
# cmap = sns.diverging_palette(-1, 1, s=100, l=50, n=15, center="dark", as_cmap=True)
plt.figure(figsize=(9, 6))
sns.heatmap(corr, annot=True, fmt='.2f', linewidth=0.5, cmap='Purples', mask=np.triu(corr))
plt.show()
# Out:
# <ipython-input-69-7841aea86bc2>:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()

# %% [markdown]
# Best Correlations are between :
# citeic_acid & flex_acidity ---> 0.67
# density & flex_acidity ---> 0.67
# total_sulfor_dioxide & free_sulfor_dioxide ---> 0.67

# %%
df = df.replace({'quality' : {8 : 'Good',
                                    7 : 'Good',
                                    6 : 'Middle',
                                    5 : 'Middle',
                                    4 : 'Bad',
                                    3 : 'Bad',
                              }
                 })

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol quality
# 0      9.4  Middle
# 1      9.8  Middle
# 2      9.8  Middle
# ...

# %%
# Create X from DataFrame and y as Target
X_temp = df.drop('quality', axis=1)
y = df['quality']

# %% [markdown]
# Lets perform the Normalisation

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1)).fit_transform(X_temp)
X = pd.DataFrame(scaler, columns=X_temp.columns)
X.describe().T.style.background_gradient(axis=0, cmap='Purples')
# Out:
# <style type="text/css">
# #T_908bd_row0_col0, #T_908bd_row0_col3, #T_908bd_row1_col0, #T_908bd_row1_col3, #T_908bd_row1_col7, #T_908bd_row2_col0, #T_908bd_row2_col3, #T_908bd_row3_col0, #T_908bd_row3_col1, #T_908bd_row3_col3, #T_908bd_row3_col5, #T_908bd_row3_col6, #T_908bd_row4_col0, #T_908bd_row4_col2, #T_908bd_row4_col3, #T_908bd_row4_col7, #T_908bd_row5_col0, #T_908bd_row5_col3, #T_908bd_row6_col0, #T_908bd_row6_col3, #T_908bd_row6_col4, #T_908bd_row6_col7, #T_908bd_row7_col0, #T_908bd_row7_col3, #T_908bd_row8_col0, #T_908bd_row8_col3, #T_908bd_row9_col0, #T_908bd_row9_col3, #T_908bd_row10_col0, #T_908bd_row10_col3 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# #T_908bd_row0_col1 {
#   background-color: #8d89c0;
#   color: #f1f1f1;
# }
# #T_908bd_row0_col2 {
#   background-color: #7b74b5;
#   color: #f1f1f1;
# }
# #T_908bd_row0_col4 {
#   background-color: #a5a2cd;
#   color: #f1f1f1;
# }
# #T_908bd_row0_col5 {
#   background-color: #9d99c7;
#   color: #f1f1f1;
# }
# ...

# %%
scaler
# Out:
# array([[0.24778761, 0.39726027, 0.        , ..., 0.60629921, 0.13772455,
#         0.15384615],
#        [0.28318584, 0.52054795, 0.        , ..., 0.36220472, 0.20958084,
#         0.21538462],
#        [0.28318584, 0.43835616, 0.04      , ..., 0.40944882, 0.19161677,
#         0.21538462],
#        ...,
#        [0.15044248, 0.26712329, 0.13      , ..., 0.53543307, 0.25149701,
#         0.4       ],
#        [0.11504425, 0.35958904, 0.12      , ..., 0.65354331, 0.22754491,
#         0.27692308],
#        [0.12389381, 0.13013699, 0.47      , ..., 0.51181102, 0.19760479,
#         0.4       ]])

# %% [markdown]
# Drawing Confusion Matrix

# %%
from sklearn import metrics
import seaborn as sns
import matplotlib.pyplot as plt

# define a function to plot confusion matrix

def plot_confusion_martix(y_test, y_pred):
  ''' plotting confusion matrix'''

  cm =  metrics.confusion_matrix(y_test, y_pred)
  ax = plt.subplot
  ax = sns.heatmap(cm, annot=True,fmt='',cmap='Purples')

  ax.set_xlabel('Predicted Labels', fontsize=18)
  ax.set_ylabel('True Labels', fontsize=18)
  ax.set_title('Confusion Matrix', fontsize=25)

  ax.xaxis.set_ticklabels(['Bad', 'Good', 'Middle'])
  ax.yaxis.set_ticklabels(['Bad', 'Good', 'Middle'])

  plt.show()

# %%
df.quality.value_counts()
# Out:
# Middle    1319
# Good       217
# Bad         63
# Name: quality, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 0)

# %% [markdown]
# Random Forest Classifer

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV, cross_val_score, KFold

# set the parameter for Random Forest

parameter = {

             'n_estimators': [50,100,150,200],
             'criterion' : ['gini', 'entropy', 'log_loss'],
             'max_features': ['sqrt', 'log2']
            }

rf = RandomForestClassifier(n_jobs=-1)
rf_cv = GridSearchCV(estimator=rf, param_grid=parameter).fit(X_train, y_train)

print('Tuned hyper parameters : ', rf_cv.best_params_)
print('accuracy : ', rf_cv.best_score_)
# Out:
# Tuned hyper parameters :  {'criterion': 'gini', 'max_features': 'sqrt', 'n_estimators': 50}
# accuracy :  0.8616207107843138

# %%
# Model :
rf = RandomForestClassifier(**rf_cv.best_params_).fit(X_train, y_train)

# %%
y_pred_rf = rf.predict(X_test)

rf_score = round(rf.score(X_test, y_test), 3)
print('RandomForestClassifier score : ', rf_score)
# Out:
# RandomForestClassifier score :  0.878

# %%
y_test.value_counts()
# Out:
# Middle    277
# Good       30
# Bad        13
# Name: quality, dtype: int64

# %%
plot_confusion_martix(y_test, y_pred_rf)

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# a dictionary to define parameters to test in algorithm
parameters = {
    'C' : [0.001, 0.01, 0.1, 1.0, 10, 100, 1000],
    'class_weight' : ['balanced'],
    'solver' : ['lbfgs', 'liblinear', 'newton-cg', 'newton-cholesky', 'sag', 'saga']
}

lr = LogisticRegression()
lr_cv = GridSearchCV(estimator=lr, param_grid= parameters, cv=10).fit(X_train, y_train)


print('Tuned hyper parameters : ', lr_cv.best_params_)
print('accuracy : ', lr_cv.best_score_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ...

# %%
#Tuned hyper parameters :  {'C': 0.1, 'class_weight': 'balanced', 'solver': 'liblinear'}
#accuracy :  0.8279773622047244
lr = LogisticRegression(**lr_cv.best_params_).fit(X_train, y_train)

# %%
y_pred_lr = lr.predict(X_test)

lr_score = round(lr.score(X_test, y_test),3)
print("Logistic Reg score : ", lr_score)
# Out:
# Logistic Reg score :  0.859

# %%
plot_confusion_martix(y_test, y_pred_lr)

# %% [markdown]
# SVC

# %%
from sklearn.svm import SVC

# a dictionary to define parameters to test in algorithm
parameters = {
    'C' : [0.001, 0.01, 0.1, 1.0, 10, 100, 1000],
    'gamma' : [0.001, 0.01, 0.1, 1.0, 10, 100, 1000],
}



svc = SVC()
svc_cv = GridSearchCV(estimator=svc, param_grid=parameters, cv=10).fit(X_train, y_train)



print('Tuned hyper parameters : ', svc_cv.best_params_)
print('accuracy : ', svc_cv.best_score_)
# Out:
# Tuned hyper parameters :  {'C': 1.0, 'gamma': 100}
# accuracy :  0.8530019685039371

# %%
# Model
svc = SVC(**svc_cv.best_params_).fit(X_train, y_train)

# %%
y_pred_svc = svc.predict(X_test)

svc_score = round(svc.score(X_test, y_test), 3)
print('SVC Score : ', svc_score)
# Out:
# SVC Score :  0.894

# %%
plot_confusion_martix(y_test, y_pred_svc)

# %% [markdown]
#  DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier
import numpy as np

# a dictionary to define parameters to test in algorithm
parameters = {
    'criterion' : ['gini', 'entropy', 'log_loss'],
    'splitter' : ['best', 'random'],
    'max_depth' : list(np.arange(4, 30, 1))
        }



tree = DecisionTreeClassifier()
tree_cv = GridSearchCV(estimator=tree, cv=10, param_grid=parameters).fit(X_train, y_train)



print('Tuned hyper parameters : ', tree_cv.best_params_)
print('accuracy : ', tree_cv.best_score_)
# Out:
# Tuned hyper parameters :  {'criterion': 'gini', 'max_depth': 5, 'splitter': 'random'}
# accuracy :  0.8350270669291339

# %%
tree = DecisionTreeClassifier(**tree_cv.best_params_).fit(X_train, y_train)

# %%
y_pred_tree = tree.predict(X_test)

tree_score = round(tree.score(X_test, y_test), 3)
print('DecisionTreeClassifier Score : ', tree_score)
# Out:
# DecisionTreeClassifier Score :  0.85

# %%
plot_confusion_martix(y_test, y_pred_tree)

# %% [markdown]
#  KNeighborsClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# a dictionary to define parameters to test in algorithm
parameters = {
    'n_neighbors' : list(np.arange(3, 50, 2)),
    'weights': ['uniform', 'distance'],
    'p' : [1, 2, 3, 4]
}

knn = KNeighborsClassifier()
knn_cv = GridSearchCV(estimator=knn, cv=10, param_grid=parameters).fit(X_train, y_train)

print('Tuned hyper parameters : ', knn_cv.best_params_)
print('accuracy : ', knn_cv.best_score_)
# Out:
# Tuned hyper parameters :  {'n_neighbors': 29, 'p': 1, 'weights': 'distance'}
# accuracy :  0.860070127952756

# %%
knn = KNeighborsClassifier(**knn_cv.best_params_).fit(X_train, y_train)

# %%
y_pred_knn = knn_cv.predict(X_test)

knn_score = round(knn.score(X_test, y_test), 3)
print('KNeighborsClassifier Score :', knn_score)
# Out:
# KNeighborsClassifier Score : 0.875

# %%
plot_confusion_martix(y_test, y_pred_knn)

# %%
result = pd.DataFrame({
    'Algorithm' : ['RandomForestClassifier', 'LogisticRegression', 'SVC', 'DecisionTreeClassifier', 'KNeighborsClassifier'],
    'Score' : [rf_score, lr_score, svc_score, tree_score, knn_score]
})

result.sort_values(by='Score', inplace=True)

# %%
result
# Out:
#                 Algorithm  Score
# 3  DecisionTreeClassifier  0.850
# 1      LogisticRegression  0.859
# 4    KNeighborsClassifier  0.875
# 0  RandomForestClassifier  0.878
# 2                     SVC  0.894

# %%
sns.set_palette("Purples")

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 5))

sns.barplot(x='Algorithm', y='Score', data=result)
ax.bar_label(ax.containers[0], fmt='%.3f')
ax.set_xticklabels(labels=result.Algorithm, rotation=300)
plt.show()
